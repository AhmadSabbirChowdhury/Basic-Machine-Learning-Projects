# %%
import pandas as pd

# %%
#read csv file
covid = pd.read_csv("CovidData.csv")

# %%
covid.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# ...

# %%
#total shape
covid.shape
# Out:
# (19918, 32)

# %%
covid.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
#looking at different location
covid["location"].value_counts()
# Out:
# Croatia           148
# Norway            148
# Malaysia          148
# Denmark           148
# Australia         148
#                  ...
# Yemen              47
# Western Sahara     31
# Tajikistan         26
# Comoros            25
# Lesotho            12
# Name: location, Length: 212, dtype: int64

# %%
#checking for null value
covid.isna().any()
# Out:
# iso_code                            True
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million             True
# new_cases_per_million               True
# total_deaths_per_million            True
# new_deaths_per_million              True
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                          True
# population_density                  True
# median_age                          True
# aged_65_older                       True
# ...

# %%
#sum of null values
covid.isna().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14631
# new_tests                          15219
# total_tests_per_thousand           14631
# new_tests_per_thousand             15219
# new_tests_smoothed                 14133
# new_tests_smoothed_per_thousand    14133
# tests_units                        13534
# stringency_index                    4365
# population                            64
# population_density                   874
# median_age                          1791
# aged_65_older                       2034
# ...

# %%
#Getting Covid Cases in Bangladesh
bangladesh_case = covid[covid["location"]=="Bangladesh"]

# %%
bangladesh_case.head(-10)
# Out:
#      iso_code    location        date  total_cases  new_cases  total_deaths  \
# 1755      BGD  Bangladesh  2020-03-04            0          0             0
# 1756      BGD  Bangladesh  2020-03-05            0          0             0
# 1757      BGD  Bangladesh  2020-03-06            0          0             0
# 1758      BGD  Bangladesh  2020-03-07            0          0             0
# 1759      BGD  Bangladesh  2020-03-08            0          0             0
# ...       ...         ...         ...          ...        ...           ...
# 1824      BGD  Bangladesh  2020-05-12        15691       1034           239
# 1825      BGD  Bangladesh  2020-05-13        16660        969           250
# 1826      BGD  Bangladesh  2020-05-14        17822       1162           269
# 1827      BGD  Bangladesh  2020-05-15        18863       1041           283
# 1828      BGD  Bangladesh  2020-05-16        20065       1202           298
#
# ...

# %%
bangladesh_case.tail()
# Out:
#      iso_code    location        date  total_cases  new_cases  total_deaths  \
# 1834      BGD  Bangladesh  2020-05-22        28511       1773           408
# 1835      BGD  Bangladesh  2020-05-23        30205       1694           432
# 1836      BGD  Bangladesh  2020-05-24        32078       1873           452
# 1837      BGD  Bangladesh  2020-05-25        33610       1532           480
# 1838      BGD  Bangladesh  2020-05-26        35585       1975           501
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1834          22                  173.120                 10.766
# 1835          24                  183.406                 10.286
# 1836          20                  194.779                 11.373
# 1837          28                  204.081                  9.302
# 1838          21                  216.073                 11.992
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
#importing visualizing libraries
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#total cases in respect to date
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases", data=bangladesh_case)
plt.show()

# %%
#dataframe for last 10 days
BD_last_10Days = bangladesh_case.tail(10)
print(BD_last_10Days)
# Out:
#      iso_code    location        date  total_cases  new_cases  total_deaths  \
# 1829      BGD  Bangladesh  2020-05-17        20995        930           314
# 1830      BGD  Bangladesh  2020-05-18        22268       1273           328
# 1831      BGD  Bangladesh  2020-05-19        23870       1602           349
# 1832      BGD  Bangladesh  2020-05-20        25121       1251           370
# 1833      BGD  Bangladesh  2020-05-21        26738       1617           386
# 1834      BGD  Bangladesh  2020-05-22        28511       1773           408
# 1835      BGD  Bangladesh  2020-05-23        30205       1694           432
# 1836      BGD  Bangladesh  2020-05-24        32078       1873           452
# 1837      BGD  Bangladesh  2020-05-25        33610       1532           480
# 1838      BGD  Bangladesh  2020-05-26        35585       1975           501
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1829          16                  127.482                  5.647
# ...

# %%
#total cases in Bangladesh for last 10 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases", data=BD_last_10Days)
plt.show()

# %%
#total tests of covid in Bangladesh 
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests", data=bangladesh_case)
plt.show()

# %%
#total tests of covid in Bangladesh (last 10 days)
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests", data=BD_last_10Days)
plt.show()

# %%
#Getting Covid Cases in India
india_case = covid[covid["location"]=="India"]
india_case.head(10)
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8560      IND    India  2019-12-31            0          0             0
# 8561      IND    India  2020-01-01            0          0             0
# 8562      IND    India  2020-01-02            0          0             0
# 8563      IND    India  2020-01-03            0          0             0
# 8564      IND    India  2020-01-04            0          0             0
# 8565      IND    India  2020-01-05            0          0             0
# 8566      IND    India  2020-01-06            0          0             0
# 8567      IND    India  2020-01-07            0          0             0
# 8568      IND    India  2020-01-08            0          0             0
# 8569      IND    India  2020-01-09            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8560           0                      0.0                    0.0
# ...

# %%
#Getting Covid Cases in India
india_case = covid[covid["location"]=="India"]
india_case.tail(10)
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8697      IND    India  2020-05-17        90927       4987          2872
# 8698      IND    India  2020-05-18        96169       5242          3029
# 8699      IND    India  2020-05-19       101139       4970          3163
# 8700      IND    India  2020-05-20       106750       5611          3303
# 8701      IND    India  2020-05-21       112359       5609          3435
# 8702      IND    India  2020-05-22       118447       6088          3583
# 8703      IND    India  2020-05-23       125101       6654          3720
# 8704      IND    India  2020-05-24       131868       6767          3867
# 8705      IND    India  2020-05-25       138845       6977          4021
# 8706      IND    India  2020-05-26       145380       6535          4167
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8697         120                   65.889                  3.614
# ...

# %%
#total cases in India with respect to date
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases", data=india_case)
plt.show()

# %%
#plotting growth of cases in Bangladesh (bar graph)
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location", y="total_cases", data=bangladesh_case, hue="date")
plt.show()

# %%
#getting latest data
last_day_cases = covid[covid["date"]== "2020-05-26"]
last_day_cases
# Out:
#        iso_code      location        date  total_cases  new_cases  \
# 64          ABW         Aruba  2020-05-26          101          0
# 202         AFG   Afghanistan  2020-05-26        11173        591
# 268         AGO        Angola  2020-05-26           69          0
# 329         AIA      Anguilla  2020-05-26            3          0
# 408         ALB       Albania  2020-05-26         1004          6
# ...         ...           ...         ...          ...        ...
# 19459       YEM         Yemen  2020-05-26          237         15
# 19569       ZAF  South Africa  2020-05-26        23615       1032
# 19638       ZMB        Zambia  2020-05-26          920          0
# 19705       ZWE      Zimbabwe  2020-05-26           56          0
# 19853  OWID_WRL         World  2020-05-26      5459526      88239
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 64                3           0                  945.994
# ...

# %%
#sorting data w.r.t total cases
max_cases_country = last_day_cases.sort_values(by="total_cases", ascending=False)
max_cases_country
# Out:
#        iso_code                         location        date  total_cases  \
# 19853  OWID_WRL                            World  2020-05-26      5459526
# 18786       USA                    United States  2020-05-26      1662302
# 2711        BRA                           Brazil  2020-05-26       374898
# 15894       RUS                           Russia  2020-05-26       353427
# 6739        GBR                   United Kingdom  2020-05-26       261184
# ...         ...                              ...         ...          ...
# 19129       VGB           British Virgin Islands  2020-05-26            8
# 1679        BES  Bonaire Sint Eustatius and Saba  2020-05-26            7
# 5663        ESH                   Western Sahara  2020-05-26            6
# 329         AIA                         Anguilla  2020-05-26            3
# 11319       LSO                          Lesotho  2020-05-26            2
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# ...

# %%
#Top 5 countries with max cases
max_cases_country[1:6]
# Out:
#       iso_code        location        date  total_cases  new_cases  \
# 18786      USA   United States  2020-05-26      1662302      19064
# 2711       BRA          Brazil  2020-05-26       374898      11687
# 15894      RUS          Russia  2020-05-26       353427       8946
# 6739       GBR  United Kingdom  2020-05-26       261184       1625
# 9591       ITA           Italy  2020-05-26       230158        300
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 18786         98220         500                 5022.020
# 2711          23473         807                 1763.733
# 15894          3633          92                 2421.820
# 6739          36914         121                 3847.391
# 9591          32877          92                 3806.666
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 18786                 57.595                   296.735  ...         15.413
# ...

# %%
#Top 5 countries with max cases bar plot
sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="location")
plt.show()

# %%
bangladesh_case.head()
# Out:
#      iso_code    location        date  total_cases  new_cases  total_deaths  \
# 1755      BGD  Bangladesh  2020-03-04            0          0             0
# 1756      BGD  Bangladesh  2020-03-05            0          0             0
# 1757      BGD  Bangladesh  2020-03-06            0          0             0
# 1758      BGD  Bangladesh  2020-03-07            0          0             0
# 1759      BGD  Bangladesh  2020-03-08            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1755           0                      NaN                    NaN
# 1756           0                      NaN                    NaN
# 1757           0                      NaN                    NaN
# 1758           0                      NaN                    NaN
# 1759           0                      NaN                    NaN
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
#Linear Regression
from sklearn.model_selection import train_test_split

# %%
#convert string date to datetime
import datetime as dt
bangladesh_case['date'] = pd.to_datetime(bangladesh_case['date'])
bangladesh_case.head()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      iso_code    location       date  total_cases  new_cases  total_deaths  \
# 1755      BGD  Bangladesh 2020-03-04            0          0             0
# 1756      BGD  Bangladesh 2020-03-05            0          0             0
# 1757      BGD  Bangladesh 2020-03-06            0          0             0
# 1758      BGD  Bangladesh 2020-03-07            0          0             0
# 1759      BGD  Bangladesh 2020-03-08            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
#converting datetime to ordinal
bangladesh_case['date'] = bangladesh_case['date'].map(dt.datetime.toordinal)
bangladesh_case.head()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      iso_code    location    date  total_cases  new_cases  total_deaths  \
# 1755      BGD  Bangladesh  737488            0          0             0
# 1756      BGD  Bangladesh  737489            0          0             0
# 1757      BGD  Bangladesh  737490            0          0             0
# 1758      BGD  Bangladesh  737491            0          0             0
# 1759      BGD  Bangladesh  737492            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1755           0                      NaN                    NaN
# ...

# %%
#Getting dependent variable and independent variable
x = bangladesh_case['date']
y = bangladesh_case['total_cases']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression

# %%
#Storing the instance in an object
lr = LinearRegression()

# %%
import numpy as np

#x_train and y_train into "numpy_array" and reshaping them in a single dimention
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
bangladesh_case.tail()
# Out:
#      iso_code    location    date  total_cases  new_cases  total_deaths  \
# 1834      BGD  Bangladesh  737567        28511       1773           408
# 1835      BGD  Bangladesh  737568        30205       1694           432
# 1836      BGD  Bangladesh  737569        32078       1873           452
# 1837      BGD  Bangladesh  737570        33610       1532           480
# 1838      BGD  Bangladesh  737571        35585       1975           501
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1834          22                  173.120                 10.766
# 1835          24                  183.406                 10.286
# 1836          20                  194.779                 11.373
# 1837          28                  204.081                  9.302
# 1838          21                  216.073                 11.992
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 1834                     2.477  ...          5.098          3.262
# ...

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
#x_test will denote all the "actual values" and y_pred will denoted all the "predicted values"
from sklearn.metrics import mean_squared_error
mean_squared_error(x_test,y_pred)
# Out:
# 533653049741.00385

# %%
## The model we created is not accurate as the mean_squared_error is really big

# %%
lr.predict(np.array([[737572]]))
# Out:
# array([[20511.76603004]])

# %%
#total cases already exceeded 35585, so predicted value is not correct
